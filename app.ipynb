# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
file_path = ''
file_name = 'train.csv'

# %%
data = pd.read_csv(file_path + file_name)

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
y = data.SalePrice

# %%
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = data[features]

# %%
X.describe()
# Out:
#              LotArea    YearBuilt     1stFlrSF     2ndFlrSF     FullBath  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082  1971.267808  1162.626712   346.992466     1.565068
# std      9981.264932    30.202904   386.587738   436.528436     0.550916
# min      1300.000000  1872.000000   334.000000     0.000000     0.000000
# 25%      7553.500000  1954.000000   882.000000     0.000000     1.000000
# 50%      9478.500000  1973.000000  1087.000000     0.000000     2.000000
# 75%     11601.500000  2000.000000  1391.250000   728.000000     2.000000
# max    215245.000000  2010.000000  4692.000000  2065.000000     3.000000
#
#        BedroomAbvGr  TotRmsAbvGrd
# count   1460.000000   1460.000000
# mean       2.866438      6.517808
# std        0.815778      1.625393
# min        0.000000      2.000000
# 25%        2.000000      5.000000
# 50%        3.000000      6.000000
# 75%        3.000000      7.000000
# ...

# %%
X.head()
# Out:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd
# 0             8
# 1             6
# 2             6
# 3             7
# 4             9

# %%
model = DecisionTreeRegressor(random_state=0)
model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
predictions = model.predict(X)
predictions
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.])

# %% [markdown]
# # Model validation

# %% [markdown]
# Note: This is a "In-Sample" Score -> use train_test_split

# %%
mean_absolute_error(y, predictions)
# Out:
# 62.35433789954339

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=0)

# %%
model = DecisionTreeRegressor(random_state=0)
model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
predictions = model.predict(val_X)

# %%
mean_absolute_error(val_y, predictions)
# Out:
# 32410.824657534245

# %% [markdown]
# # Improvement with max_leaf_nodes

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    predictions = model.predict(val_X)
    mae = mean_absolute_error(val_y, predictions)
    return mae

# %%
mae = {}
for max_leaf_nodes in range(5, 100, 5):
    mae[max_leaf_nodes] = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print(f'Max Leaf Nodes: {max_leaf_nodes} \t \t MAE: {mae[max_leaf_nodes]}')
# Out:
# Max Leaf Nodes: 5 	 	 MAE: 35190.33670788684
# Max Leaf Nodes: 10 	 	 MAE: 30616.34246307534
# Max Leaf Nodes: 15 	 	 MAE: 29666.693434223555
# Max Leaf Nodes: 20 	 	 MAE: 29206.714769038022
# Max Leaf Nodes: 25 	 	 MAE: 28501.887126575195
# Max Leaf Nodes: 30 	 	 MAE: 28302.01671291155
# Max Leaf Nodes: 35 	 	 MAE: 27556.9435800501
# Max Leaf Nodes: 40 	 	 MAE: 27570.287821320566
# Max Leaf Nodes: 45 	 	 MAE: 27531.646484135945
# Max Leaf Nodes: 50 	 	 MAE: 27825.888386265695
# Max Leaf Nodes: 55 	 	 MAE: 27881.12256760947
# Max Leaf Nodes: 60 	 	 MAE: 28072.610258049415
# Max Leaf Nodes: 65 	 	 MAE: 27976.76593264674
# Max Leaf Nodes: 70 	 	 MAE: 27657.220980730024
# Max Leaf Nodes: 75 	 	 MAE: 27455.53740524919
# Max Leaf Nodes: 80 	 	 MAE: 27280.23209035945
# Max Leaf Nodes: 85 	 	 MAE: 27648.29847667257
# Max Leaf Nodes: 90 	 	 MAE: 28284.726891271668
# Max Leaf Nodes: 95 	 	 MAE: 28503.81217468655

# %% [markdown]
# # Improvment with RandomForest

# %%
model = RandomForestRegressor(random_state=1)
model.fit(train_X, train_y)
# Out:
# RandomForestRegressor(random_state=1)

# %%
predictions = model.predict(val_X)

# %%
mean_absolute_error(val_y, predictions)
# Out:
# 23009.206570906717
